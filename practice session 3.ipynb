# %% [markdown]
# # list

# %%
["20k","30k","40k","45k","50k","55k","60k"]
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
salaries =  ["20k","30k","40k","45k","50k","55k","60k"]

# %%
salaries
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
salaries[1]
# Out:
# '30k'

# %%
salaries[]
# Out:
#   Cell In[5], line 1
#     salaries[]
#              ^
# SyntaxError: invalid syntax

# %%
salaries[6]
# Out:
# '60k'

# %%
salaries[3:4]
# Out:
# ['45k']

# %%
salaries[4:6]
# Out:
# ['50k', '55k']

# %%
salaries
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
len(salaries)
# Out:
# 7

# %% [markdown]
# # Indexing

# %%
salaries
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
salaries[0]
# Out:
# '20k'

# %%
salaries[4]
# Out:
# '50k'

# %%
salaries[-3]
# Out:
# '50k'

# %%
salaries[-0]
# Out:
# '20k'

# %%
salaries[-5:-2]
# Out:
# ['40k', '45k', '50k']

# %%
bio = ["sara",45,salaries,"ashar","ashar.0711@mail", 65.99]

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
bio[0]
# Out:
# 'sara'

# %%
bio[3]
# Out:
# 'ashar'

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
bio[2]
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
bio[2][5]
# Out:
# '55k'

# %%
bio[2][5:1]
# Out:
# []

# %%
bio[2][1:4]
# Out:
# ['30k', '40k', '45k']

# %%
bio[2][0:5]
# Out:
# ['20k', '30k', '40k', '45k', '50k']

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
bio[2][-7:-3]
# Out:
# ['20k', '30k', '40k', '45k']

# %%
bio[2][-6:-2]
# Out:
# ['30k', '40k', '45k', '50k']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_18',
#  '_19',
#  '_20',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_4',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'bio',
#  'exit',
# ...

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(<>)
# Out:
#   Cell In[41], line 1
#     dir(<>)
#         ^
# SyntaxError: invalid syntax

# %%
dir(\/)
# Out:
#   Cell In[42], line 1
#     dir(\/)
#          ^
# SyntaxError: unexpected character after line continuation character

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(goto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dir(goto)
#
# NameError: name 'goto' is not defined

# %%
dir(ifgoto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 dir(ifgoto)
#
# NameError: name 'ifgoto' is not defined

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
type(salaries)
# Out:
# list

# %%
type(salaries)
# Out:
# list

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
bio.index("sara")
# Out:
# 0

# %%
bio.index("ashar")
# Out:
# 3

# %%
bio.index("ashar.0711@mail")
# Out:
# 4

# %%
bio.index(65.99)
# Out:
# 5

# %%
bio.index(['20k', '30k', '40k', '45k', '50k', '55k', '60k'])
# Out:
# 2

# %%
salaries
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
salaries[0:]
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
salaries[:6]
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k']

# %%
salaries[:]
# Out:
# ['20k', '30k', '40k', '45k', '50k', '55k', '60k']

# %%
bio
# Out:
# ['sara',
#  45,
#  ['20k', '30k', '40k', '45k', '50k', '55k', '60k'],
#  'ashar',
#  'ashar.0711@mail',
#  65.99]

# %%
print(bio)
# Out:
# ['sara', 45, ['20k', '30k', '40k', '45k', '50k', '55k', '60k'], 'ashar', 'ashar.0711@mail', 65.99]

# %%
bio.index(45)
# Out:
# 1

# %%
bio.index("ashar")
# Out:
# 3

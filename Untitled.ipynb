# %% [markdown]
# # List

# %%
[20k,30k,40k,50k,60k]
# Out:
#   Cell In[1], line 1
#     [20k,30k,40k,50k,60k]
#       ^
# SyntaxError: invalid decimal literal

# %%
["20k","30k","40k","50k","60k"]
# Out:
# ['20k', '30k', '40k', '50k', '60k']

# %%
salaries = ["20k","25k","30k","35k","40k","45k"]

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
len(salaries)
# Out:
# 6

# %% [markdown]
# # Indexing

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries[3]
# Out:
# '35k'

# %%
salaries[0]
# Out:
# '20k'

# %%
salaries[1]
# Out:
# '25k'

# %%
salaries[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 salaries[6]
#
# IndexError: list index out of range

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries[-5]
# Out:
# '25k'

# %%
salaries[0]
# Out:
# '20k'

# %%
salaries[-3]
# Out:
# '35k'

# %% [markdown]
# # BIO

# %%
bio = ["Sana",25,salaries,45.89,"sara@123"]

# %%
bio
# Out:
# ['Sana', 25, ['20k', '25k', '30k', '35k', '40k', '45k'], 45.89, 'sara@123']

# %%
bio[0]
# Out:
# 'Sana'

# %%
bio[-1]
# Out:
# 'sara@123'

# %%
bio[2]
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
bio[2][4]
# Out:
# '40k'

# %%
bio[1]
# Out:
# 25

# %%
bio[2][5]
# Out:
# '45k'

# %% [markdown]
# # Slicing

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries[0:3]
# Out:
# ['20k', '25k', '30k']

# %%
salaries[1:5]
# Out:
# ['25k', '30k', '35k', '40k']

# %%
salaries[-1:-3]
# Out:
# []

# %%
salaries[-3:-2]
# Out:
# ['35k']

# %%
salaries[-6:-2]
# Out:
# ['20k', '25k', '30k', '35k']

# %%
salaries[-6:1]
# Out:
# ['20k']

# %%
salaries[:5]
# Out:
# ['20k', '25k', '30k', '35k', '40k']

# %%
salaries[:6]
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries[:-6]
# Out:
# []

# %%
salaries[-6:]
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
salaries[1:3:5]
# Out:
# ['25k']

# %%
salaries[0:2:3]
# Out:
# ['20k']

# %% [markdown]
# # Directories

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
type(salaries)
# Out:
# list

# %%
bio.index("sara@123")
# Out:
# 4

# %%
bio.index("sara@123")
# Out:
# 4

# %%
bio
# Out:
# ['Sana', 25, ['20k', '25k', '30k', '35k', '40k', '45k'], 45.89, 'sara@123']

# %%
print(bio)
# Out:
# ['Sana', 25, ['20k', '25k', '30k', '35k', '40k', '45k'], 45.89, 'sara@123']

# %%
print(salaries)
# Out:
# ['20k', '25k', '30k', '35k', '40k', '45k']

# %%
print(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(index)
#
# NameError: name 'index' is not defined

# %%
print(type)
# Out:
# <class 'type'>

# %%
print(slicing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(slicing)
#
# NameError: name 'slicing' is not defined

# %%
print(dir)
# Out:
# <built-in function dir>

# %%
bio.index("sara@123")
# Out:
# 4

# %%
bio.dir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 bio.dir
#
# AttributeError: 'list' object has no attribute 'dir'

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_17',
#  '_18',
#  '_19',
#  '_2',
#  '_20',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_40',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_46',
#  '_47',
#  '_48',
#  '_49',
#  '_5',
#  '_50',
#  '_51',
#  '_54',
#  '_55',
#  '_56',
#  '_63',
#  '_65',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
# ...

# %%
dir
# Out:
# <function dir>

# %%
loop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 loop
#
# NameError: name 'loop' is not defined

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

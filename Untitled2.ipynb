# %% [markdown]
# ### 1. Add the number 10 to the end of the list using method.
# nums = [1, 2, 3]

# %%
nums = [1,2,3]

# %%
nums
# Out:
# [1, 2, 3]

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'nums',
#  'open',
#  'quit']

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
nums
# Out:
# [1, 2, 3]

# %%
nums.append(10)

# %%
nums
# Out:
# [1, 2, 3, 10]

# %% [markdown]
# ### 2. A customer orders several food items. Add the items to a list and then:
# order = ["burger", "fries", "coke"]
# Add a new item "ice cream" using append()
# Remove an item "biryani" using remove()
# Show the final order

# %%
order = ["burger", "fries", "coke"]

# %%
order
# Out:
# ['burger', 'fries', 'coke']

# %%
order.append("ice cream")

# %%
order
# Out:
# ['burger', 'fries', 'coke', 'ice cream']

# %%
order.append("biryani")

# %%
order
# Out:
# ['burger', 'fries', 'coke', 'ice cream', 'biryani']

# %%
order.remove("biryani")

# %%
order
# Out:
# ['burger', 'fries', 'coke', 'ice cream']

# %% [markdown]
# ### 3. Sort the list in ascending order using method
# nums = [4, 1, 3, 2]

# %%
nums = [4, 1, 3, 2]

# %%
nums
# Out:
# [4, 1, 3, 2]

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 4. Track passengers on a bus:
# passengers = ["Ali", "Zara", "Ahmed"]
# Insert a new passenger "Sara" at position 2
# Remove passesnger who got off "Zara"¶
# Reverse the order to show who entered first

# %%
passengers = ["Ali", "Zara", "Ahmed"]

# %%
passengers
# Out:
# ['Ali', 'Zara', 'Ahmed']

# %%
passengers.insert(2,"Sara")

# %%
passengers
# Out:
# ['Ali', 'Zara', 'Sara', 'Ahmed']

# %%
passengers.remove('Zara')

# %%
passengers
# Out:
# ['Ali', 'Sara', 'Ahmed']

# %%
passengers.reverse()

# %%
passengers
# Out:
# ['Ahmed', 'Sara', 'Ali']

# %% [markdown]
# ### 5. text = 'hello python world'
# Replace spaces with underscores in the string (e.g., "hello python world" → "hello_python_world").
# Split the modified string (e.g., "hello_python_world" → ['hello', 'python', 'world']).
# Join the list elements with a hyphen (-) between them (e.g., ['hello', 'python', 'world'] → "hello-python-world").
# Print all three results
# Hint: Use string methods¶

# %%
text = 'hello python world'

# %%
text
# Out:
# 'hello python world'

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_100',
#  '_102',
#  '_104',
#  '_106',
#  '_108',
#  '_11',
#  '_110',
#  '_13',
#  '_15',
#  '_17',
#  '_19',
#  '_2',
#  '_21',
#  '_23',
#  '_25',
#  '_27',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_33',
#  '_34',
#  '_36',
#  '_37',
#  '_39',
#  '_4',
#  '_40',
#  '_43',
#  '_44',
#  '_48',
#  '_49',
#  '_5',
#  '_50',
#  '_51',
#  '_52',
#  '_53',
#  '_54',
#  '_55',
#  '_56',
#  '_57',
#  '_59',
#  '_61',
#  '_63',
#  '_64',
#  '_65',
#  '_66',
#  '_67',
#  '_68',
#  '_69',
#  '_7',
#  '_71',
#  '_73',
#  '_74',
#  '_76',
#  '_77',
#  '_79',
#  '_80',
#  '_81',
#  '_83',
#  '_85',
#  '_86',
#  '_88',
#  '_9',
#  '_90',
#  '_92',
#  '_94',
#  '_96',
#  '_98',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i100',
#  '_i101',
#  '_i102',
#  '_i103',
#  '_i104',
#  '_i105',
#  '_i106',
#  '_i107',
#  '_i108',
#  '_i109',
#  '_i11',
#  '_i110',
#  '_i111',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i73',
#  '_i74',
#  '_i75',
#  '_i76',
#  '_i77',
#  '_i78',
#  '_i79',
#  '_i8',
#  '_i80',
#  '_i81',
#  '_i82',
#  '_i83',
#  '_i84',
#  '_i85',
#  '_i86',
#  '_i87',
#  '_i88',
#  '_i89',
#  '_i9',
#  '_i90',
#  '_i91',
#  '_i92',
#  '_i93',
#  '_i94',
#  '_i95',
#  '_i96',
#  '_i97',
#  '_i98',
#  '_i99',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'cities',
#  'data',
#  'exit',
#  'format',
#  'get_ipython',
#  'hyphen',
#  'nums',
#  'open',
#  'order',
#  'passengers',
#  'quit',
#  'split',
#  'text',
#  'underscore',
#  'word']

# %%
text
# Out:
# 'hello python world'

# %%
underscore = "hello python world"

# %%
underscore
# Out:
# 'hello python world'

# %%
underscore.replace(" ","_")    # underscore
# Out:
# 'hello_python_world'

# %%
split = "hello python world"

# %%
split
# Out:
# 'hello python world'

# %%
split.split()   # solo split
# Out:
# ['hello', 'python', 'world']

# %%
hyphen = "hello python world"

# %%
hyphen
# Out:
# 'hello python world'

# %%
hyphen.replace(" ","-")   # using dash
# Out:
# 'hello-python-world'

# %%
underscore = "hello_python_world"
split = ['hello', 'python', 'world']
hyphen = "hello-python-world"
print(f'Firstly I mention {underscore}, then on the second place I mention {split} and after all of this the last one is {hyphen}')
# Out:
# Firstly I mention hello_python_world, then on the second place I mention ['hello', 'python', 'world'] and after all of this the last one is hello-python-world

# %% [markdown]
# ### 6. Check if a string has more than 5 characters. Return True/False
# word = "Javascript"¶

# %%
word = "Javascript"

# %%
word
# Out:
# 'Javascript'

# %%
word
# Out:
# 'Javascript'

# %%
print(len(word))
# Out:
# 10

# %%
print(len(word) > 5)
# Out:
# True

# %% [markdown]
# ### 7. You have a product code that follows the format "SKU-12345-XYZ".
# Find the first position of the dash (-).
# Count the number of dashes (-) in the product code.
# Remove the "SKU-" prefix and "-XYZ" suffix from the product code, Extract the numeric part 12345
# Hint: Use String Methods¶

# %%
format ="SKU-12345-XYZ"

# %%
format
# Out:
# 'SKU-12345-XYZ'

# %%
format.index("-")   #### postion
# Out:
# 3

# %%
format
# Out:
# 'SKU-12345-XYZ'

# %%
format.count("-")    ##### count
# Out:
# 2

# %%
format
# Out:
# 'SKU-12345-XYZ'

# %%
format.removeprefix("SKU-")  #### removing prefix
# Out:
# '12345-XYZ'

# %%
format
# Out:
# 'SKU-12345-XYZ'

# %%
format.removesuffix("-XYZ")     #### removing suffix
# Out:
# 'SKU-12345'

# %%
format
# Out:
# 'SKU-12345-XYZ'

# %%
format.split("-")[1]  ### extracting the number
# Out:
# '12345'

# %% [markdown]
# ### 8. Given the following list:
# cities = ["Karachi", "Lahore", "Islamabad", "Quetta"]
# Use the reverse() method and display the reversed list.¶

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Quetta"]

# %%
cities
# Out:
# ['Karachi', 'Lahore', 'Islamabad', 'Quetta']

# %%
cities.reverse()

# %%
cities
# Out:
# ['Quetta', 'Islamabad', 'Lahore', 'Karachi']

# %% [markdown]
# ### 9. text = " Data Analysis with Python is very powerful "
# Perform the following tasks:
# Remove extra spaces using strip().
# Convert the string into title case using title().
# Replace "Powerful" with "Important".
# Find the position of the word "Python".

# %%
text = " Data Analysis with Python is very powerful "

# %%
text
# Out:
# ' Data Analysis with Python is very powerful '

# %%
text.strip() ### removing extra spaces
# Out:
# 'Data Analysis with Python is very powerful'

# %%
text.title()
# Out:
# ' Data Analysis With Python Is Very Powerful '

# %%
text
# Out:
# ' Data Analysis with Python is very powerful '

# %%
text.replace("powerful","important") ### removing of word with the new one
# Out:
# ' Data Analysis with Python is very important '

# %%
text
# Out:
# ' Data Analysis with Python is very powerful '

# %%
text.index("Python")  ### finding the postion of "Python"
# Out:
# 20

# %% [markdown]
# ## 10. Given the list:
# data = [12, 45, 2, 67, 34, 89, 23, 90]
# Perform the following tasks:
# Sort the list in ascending order.
# Remove the highest value from the list.
# Insert the value 50 at index 3.".
# Finally, reverse the updated list and display the result.

# %%
data = [12, 45, 2, 67, 34, 89, 23, 90]

# %%
data
# Out:
# [12, 45, 2, 67, 34, 89, 23, 90]

# %%
data.sort()    #### ascending order

# %%
data
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]

# %%
data
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]

# %%
data.remove(90)

# %%
data
# Out:
# [2, 12, 23, 34, 45, 67, 89]

# %%
data  #### inserting a number : 50
# Out:
# [2, 12, 23, 34, 45, 67, 89]

# %%
data.insert(3,50)

# %%
data
# Out:
# [2, 12, 23, 50, 34, 45, 67, 89]

# %%
data ### reversing the list
# Out:
# [2, 12, 23, 50, 34, 45, 67, 89]

# %%
data.reverse()

# %%
data
# Out:
# [89, 67, 45, 34, 50, 23, 12, 2]

# %%
salaries = ["20k","30k","40k","50k","60k","70k","80k","90k","100k"]

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit',
#  'salaries']

# %%
dir(salaries)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
salaries.append("200k")

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k', '200k']

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k', '200k']

# %%
salaries.count("20k")
# Out:
# 1

# %%
salaries.count('50k')
# Out:
# 1

# %%
salaries.count('20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k', '200k')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 salaries.count('20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k', '200k')
#
# TypeError: list.count() takes exactly one argument (10 given)

# %%
salaries.insert(3,"49k")

# %%
salaries
# Out:
# ['20k', '30k', '40k', '49k', '50k', '60k', '70k', '80k', '90k', '100k', '200k']

# %%
salaries.index("55k",start="49k", stop="200k")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 salaries.index("55k",start="49k", stop="200k")
#
# TypeError: list.index() takes no keyword arguments

# %%
salaries.insert(0,"77k")

# %%
salaries
# Out:
# ['77k',
#  '20k',
#  '30k',
#  '40k',
#  '49k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
salaries
# Out:
# ['77k',
#  '20k',
#  '30k',
#  '40k',
#  '49k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
salaries[4]
# Out:
# '49k'

# %%
salaries[4]= "45k"

# %%
salaries
# Out:
# ['77k',
#  '20k',
#  '30k',
#  '40k',
#  '45k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
salaries[1:5]
# Out:
# ['20k', '30k', '40k', '45k']

# %%
salaries
# Out:
# ['77k',
#  '20k',
#  '30k',
#  '40k',
#  '45k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
salaries[1:4] = "21k","22k","23k"

# %%
salaries
# Out:
# ['77k',
#  '21k',
#  '22k',
#  '23k',
#  '45k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
dir[()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dir[()]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
dir[()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dir[()]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
dir[]
# Out:
#   Cell In[37], line 1
#     dir[]
#         ^
# SyntaxError: invalid syntax

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['77k',
#  '21k',
#  '22k',
#  '23k',
#  '45k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '200k']

# %%
salaries.clear()

# %%
salaries
# Out:
# []

# %%
salaries.copy()
# Out:
# []

# %%
salaries
# Out:
# []

# %%
salaries['77k','21k',
 '22k',
 '23k',
 '45k',
 '50k',
 '60k',
 '70k',
 '80k',
 '90k',
 '100k',
 '200k']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 salaries['77k',
#       2  '21k',
#       3  '22k',
#       4  '23k',
#       5  '45k',
#       6  '50k',
#       7  '60k',
#       8  '70k',
#       9  '80k',
#      10  '90k',
#      11  '100k',
#      12  '200k']
#
# TypeError: list indices must be integers or slices, not tuple

# %%
salaries = ["20k","30k","40k","50k","60k","70k","80k","90k","100k"]

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
copy= salaries.copy()

# %%
copy
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
salaries.count('30k', '40k', '50k', '60k')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 salaries.count('30k', '40k', '50k', '60k')
#
# TypeError: list.count() takes exactly one argument (4 given)

# %%
salaries.count("40k")
# Out:
# 1

# %%
salaries
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
copy
# Out:
# ['20k', '30k', '40k', '50k', '60k', '70k', '80k', '90k', '100k']

# %%
copy.count('50k')
# Out:
# 1

# %%
salaries.extend(copy)

# %%
salaries
# Out:
# ['20k',
#  '30k',
#  '40k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '20k',
#  '30k',
#  '40k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k']

# %%
copy.remove('60k')

# %%
copy
# Out:
# ['20k', '30k', '40k', '50k', '70k', '80k', '90k', '100k']

# %%
salaries
# Out:
# ['20k',
#  '30k',
#  '40k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k',
#  '20k',
#  '30k',
#  '40k',
#  '50k',
#  '60k',
#  '70k',
#  '80k',
#  '90k',
#  '100k']

# %%
copy
# Out:
# ['20k', '30k', '40k', '50k', '70k', '80k', '90k', '100k']

# %%
copy.pop(2)
# Out:
# '40k'

# %%
copy
# Out:
# ['20k', '30k', '50k', '70k', '80k', '90k', '100k']

# %%
copy.remove('100k')

# %%
copy
# Out:
# ['20k', '30k', '50k', '70k', '80k', '90k']

# %%
copy
# Out:
# ['20k', '30k', '50k', '70k', '80k', '90k']

# %%
copy.reverse()

# %%
copy
# Out:
# ['90k', '80k', '70k', '50k', '30k', '20k']

# %%
num= [0,1,2,3,5,4,3,2,56,40]

# %%
num
# Out:
# [0, 1, 2, 3, 5, 4, 3, 2, 56, 40]

# %%
num.sort()

# %%
num
# Out:
# [0, 1, 2, 2, 3, 3, 4, 5, 40, 56]

# %%
list= [10, 20, 30]

# %%
list
# Out:
# [10, 20, 30]

# %%
list.index(20,1)
# Out:
# 1

# %%
list
# Out:
# [10, 20, 30]

# %%
list
# Out:
# [10, 20, 30]

# %%
list.insert(1,15)

# %%
list
# Out:
# [10, 15, 20, 30]

# %%
list= ["banana", "apple", "mango"]

# %%
list
# Out:
# ['banana', 'apple', 'mango']

# %%
list
# Out:
# ['banana', 'apple', 'mango']

# %%
list.remove('apple')

# %%
list
# Out:
# ['banana', 'mango']

# %%
salaries = [5, 2, 9, 1, 7]

# %%
salaries.sort()

# %%
salaries
# Out:
# [1, 2, 5, 7, 9]

# %%
fruits = ["apple", "mango", "banana"]

# %%
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
fruits.index('mango',0,2)
# Out:
# 1

# %% [raw]
# fruits.index('banana',0,2)

# %%
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
prog_lang = "python is a fun"

# %%
prog_lang
# Out:
# 'python is a fun'

# %%
type(prog_lang)
# Out:
# str

# %%
dir(prog_lang)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
prog_lang
# Out:
# 'python is a fun'

# %%
prog_lang.capitalize()
# Out:
# 'Python is a fun'

# %%
prog_lang
# Out:
# 'python is a fun'

# %%
prog_lang.upper()
# Out:
# 'PYTHON IS A FUN'

# %%
prog_lang
# Out:
# 'python is a fun'

# %%
prog_lang.replace(python,java,count =0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 prog_lang.replace(python,java,count =0)
#
# NameError: name 'python' is not defined

# %%
prog_lang
# Out:
# 'python is a fun'

# %%
prog_lang.lower()
# Out:
# 'python is a fun'

# %%
prog_lang.title()
# Out:
# 'Python Is A Fun'

# %%
'Python Is A Fun'.isnumeric()
# Out:
# False

# %%
"1234".isnumeric()
# Out:
# True

# %%
"12w3".isalpha()
# Out:
# False

# %%
"qwerty".isalnum()
# Out:
# True

# %%
"wqerew1234545".isalnum()
# Out:
# True

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
message = "java is a funny"

# %%
message
# Out:
# 'java is a funny'

# %%
print(message.find("funny"))
# Out:
# 10

# %%
text = "C+ is a boring"

# %%
text
# Out:
# 'C+ is a boring'

# %%
text.index("a")
# Out:
# 6

# %%
print("Hello {}, your balance is {}.".format("Adam", 230.2346))
# Out:
# Hello Adam, your balance is 230.2346.

# %%
print("Hello {}, your balance is {}.".format("Adam", 230.2346))
# Out:
# Hello Adam, your balance is 230.2346.

# %%
print("heyya {}, your balance is {}.".format("ashar",230.567))
# Out:
# heyya ashar, your balance is 230.567.

# %%
name = "ashley"
bal = 65000
print(f'Hello {name}, your balance is {bal}')
# Out:
# Hello ashley, your balance is 65000

# %%
name = "Chiara"
bal = "$2330"
print(f'Ciao {name}, tu sei casa e {bal}')
# Out:
# Ciao Chiara, tu sei casa e $2330

# %%
name = "davis"
code = 456
print(f'Hello {name}, your codec is {code}')
# Out:
# Hello davis, your codec is 456

# %%
name = "sara"
bal = 56789.4
print(f' Hello {name}, your {bal} is here from the rent')
# Out:
#  Hello sara, your 56789.4 is here from the rent

# %%
name = "sana"
col = "red color"
print(f'Hello {name}, I know you like the {col}' )
# Out:
# Hello sana, I know you like the red color

# %%
test = "  Good boy"

# %%
test
# Out:
# '  Good boy'

# %%
test.lstrip()
# Out:
# 'Good boy'

# %%
pros = "he is a good boy"

# %%
pros
# Out:
# 'he is a good boy'

# %%
pros.split()
# Out:
# ['he', 'is', 'a', 'good', 'boy']

# %%
email = "ashar malik 123"

# %%
email
# Out:
# 'ashar malik 123'

# %%
email.split()
# Out:
# ['ashar', 'malik', '123']

# %%
msg = "python is a bored"

# %%
msg
# Out:
# 'python is a bored'

# %%
msg.replace("python", "java")
# Out:
# 'java is a bored'

# %%
name = "colery"
bal = "$ 23046464.9"
print(f' Hello {name}, I have a balance of {bal} in this account')
# Out:
#  Hello colery, I have a balance of $ 23046464.9 in this account

# %%
# Remove the extra spaces from both ends of the string " Hello World ".
# Remove spaces only from the left side of " Start now".
# Remove trailing spaces from "Finish line ".
# Replace "apple" with "banana" in the sentence "I have an apple".
# Remove the .jpg suffix from "picture.jpg".
# Remove the "Mr. " prefix from "Mr. John".
# How many times does the letter "e" appear in "experience"?
# Find the position of "@" in the email "user@example.com".

# %%
print (" Hello World ")
# Out:
#  Hello World

# %%
" Hello World "
# Out:
# ' Hello World '

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
' Hello World '.strip()
# Out:
# 'Hello World'

# %% [markdown]
# ###### Remove spaces only from the left side of " Start now".

# %%
" Start now"
# Out:
# ' Start now'

# %%
" Start now".lstrip()
# Out:
# 'Start now'

# %% [markdown]
# ##### Remove trailing spaces from "Finish line ".¶

# %%
"Finish line "
# Out:
# 'Finish line '

# %%
"Finish line ".rstrip()
# Out:
# 'Finish line'

# %% [markdown]
# #### Replace "apple" with "banana" in the sentence "I have an apple".¶

# %%
"I have an apple"
# Out:
# 'I have an apple'

# %%
"I have an apple".replace("apple","banana")
# Out:
# 'I have an banana'

# %% [markdown]
# ##### Remove the .jpg suffix from "picture.jpg".

# %%
"picture.jpg"
# Out:
# 'picture.jpg'

# %%
"picture.jpg".removesuffix(".jpg")
# Out:
# 'picture'

# %% [markdown]
# ##### Remove the "Mr. " prefix from "Mr. John".

# %%
"Mr. John"
# Out:
# 'Mr. John'

# %%
"Mr. John".removeprefix("Mr.")
# Out:
# ' John'

# %%
' John'
# Out:
# ' John'

# %%
' John'.lstrip()
# Out:
# 'John'

# %% [markdown]
# #### How many times does the letter "e" appear in "experience"?

# %%
"experience"
# Out:
# 'experience'

# %%
"experience".count("e")
# Out:
# 4

# %% [markdown]
# ##### Find the position of "@" in the email "user@example.com".

# %%
"user@example.com"
# Out:
# 'user@example.com'

# %%
"user@example.com".index("@")
# Out:
# 4

# %%
"user @ example.com".split()
# Out:
# ['user', '@', 'example.com']

# %% [markdown]
# # Question 1
# ## Calculate and write the output of the following expression:
# 30 + 4 × 3 − 6

# %%
print(30+4*3-6)
# Out:
# 36

# %% [markdown]
# # Question 2
# # Calculate and write the output of the following expression:
# 100 ÷ 4 + 7 − 5

# %%
print(100/4+7-5)
# Out:
# 27.0

# %% [markdown]
# # Question 3
# ## Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.¶

# %%
num = "100"

# %%
num
# Out:
# '100'

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
num = int(num)

# %%
num
# Out:
# 100

# %%
print(type(100))
# Out:
# <class 'int'>

# %%
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# # Question 4
# ## Create the following list and display:
# cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# Second city
# Fourth city

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

# %%
cities
# Out:
# ['Karachi', 'Lahore', 'Islamabad', 'Peshawar', 'Quetta']

# %%
cities[2]
# Out:
# 'Islamabad'

# %%
cities[4]
# Out:
# 'Quetta'

# %% [markdown]
# # Question 5
# ## Create the following nested list and display:
# students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# Ali
# Ayesha

# %%
print(students)
# Out:
# [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]

# %%
students
# Out:
# [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]

# %%
students[0]
# Out:
# ['Ali', 20]

# %%
students[0][0]
# Out:
# 'Ali'

# %%
students[1]
# Out:
# ['Ayesha', 22]

# %%
students[1][0]
# Out:
# 'Ayesha'

# %% [markdown]
# # Question 6
# ## Given list:
# numbers = [10, 20, 30, 40, 50, 60, 70]
# Display:
# First 3 elements
# Last 3 elements

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

# %%
numbers
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
numbers[0:3] #First 3 elements
# Out:
# [10, 20, 30]

# %%
numbers[4:7] #last 3 elements
# Out:
# [50, 60, 70]

# %% [markdown]
# # Question 7
# ## Given nested list::
# students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# Display:
# Name of first student
# Age of second student¶

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %%
students
# Out:
# [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]

# %%
students[0][0] #Name of first student
# Out:
# 'Ali'

# %%
students[1][1] #Age of second student
# Out:
# 22

# %% [markdown]
# # Question 8
# ## Create a list of 5 fruits and display:
# First fruit
# Last fruit

# %%
fruits = ["banana", "apple", "apricot", "lychee", "mango"]

# %%
fruits
# Out:
# ['banana', 'apple', 'apricot', 'lychee', 'mango']

# %% [markdown]
# # Question 9
# ## Create the following list and display:
# colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# First color
# Last color
# using negative indexing¶

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

# %%
colors
# Out:
# ['Red', 'Blue', 'Green', 'Yellow', 'Black']

# %%
colors[-1] ##first color
# Out:
# 'Black'

# %%
colors[-5] ##last color
# Out:
# 'Red'

# %% [markdown]
# # Question 10
# ## Given nested list:
# marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# Display:
# Subject of second student,
# Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]

# %%
marks
# Out:
# [['Math', 90], ['Physics', 85], ['English', 88]]

# %%
marks[1][0]
# Out:
# 'Physics'

# %%
marks[2][1]
# Out:
# 88
